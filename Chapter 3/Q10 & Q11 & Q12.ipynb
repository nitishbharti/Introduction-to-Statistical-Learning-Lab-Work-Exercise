# %%
library('ISLR')

# %% [markdown]
# # Question 10

# %%
Carseats[1:10,]
# Out:
#    Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1   9.50 138        73    11          276        120   Bad       42  17
# 2  11.22 111        48    16          260         83   Good      65  10
# 3  10.06 113        35    10          269         80   Medium    59  12
# 4   7.40 117       100     4          466         97   Medium    55  14
# 5   4.15 141        64     3          340        128   Bad       38  13
# 6  10.81 124       113    13          501         72   Bad       78  16
# 7   6.63 115       105     0           45        108   Medium    71  15
# 8  11.85 136        81    15          425        120   Good      67  10
# 9   6.54 132       110     0          108        124   Medium    76  10
# 10  4.69 132       113     0          131        124   Medium    76  17
#    Urban US
# 1  Yes   Yes
# 2  Yes   Yes
# 3  Yes   Yes
# 4  Yes   Yes
# 5  Yes   No
# 6  No    Yes
# 7  Yes   No
# 8  Yes   Yes
# 9  No    No
# 10 No    Yes

# %% [markdown]
# ## Ans (a)

# %%
lm.fit = lm(Sales~Price+Urban+US, data=Carseats)
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Ans(b)

# %% [raw]
# P-value associated with F-square is less than 0.001, so we can say that there is an association between atleast one predictor and response.
#
# P-value associated with Price and US is strong so we can say that these two predictors are highly associated with response.
# R-squared is not atleast not grater than 0.5, so we can say that estimation function is not close to true function.

# %% [markdown]
# ## Ans(c)

# %% [raw]
# Sale ~ -0.05*Price -0.02*UrbanYes + 1.2*USYes + 13.04

# %% [markdown]
# ## Ans(d)

# %% [raw]
# For Price and US, we can reject null hypothesis as p-value corresponding to this is low.

# %% [markdown]
# ## Ans(e)

# %%
lm.fit1 = lm(Sales~Price+US, data=Carseats)
summary(lm.fit1)
# Out:
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Ans(f)

# %% [raw]
# Model (e) fits the data better than model (a), as RSS corresponding to model(e) is lesser than model (a).

# %% [markdown]
# ## Ans(g)

# %% [raw]
# Price [-0.05448-2*0.00523,  -0.05448+2*0.00523 ]
# US [1.09964-2*0.25846, 1.09964+2*0.25846]
#
# Price [-0.06494, -0.04402]
# US [0.58272, 1.61656]

# %% [markdown]
# ## Ans(h)

# %%
par(mfrow=c(2,2))
plot(lm.fit1)
# Out:
# Plot with title “”

# %% [raw]
# Yes there is outliers and high leverage points in the model(e)

# %% [markdown]
# # Question 11

# %% [markdown]
# ## Ans(a)

# %%
set.seed(1)
x= rnorm(100)
y = 2*x + rnorm(100)

# %%
plot(x,y)
# Out:
# plot without title

# %%
lm.fit = lm(y~x+0)
summary(lm.fit)
# Out:
# Call:
# lm(formula = y ~ x + 0)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9154 -0.6472 -0.1771  0.5056  2.3109
#
# Coefficients:
#   Estimate Std. Error t value Pr(>|t|)
# x   1.9939     0.1065   18.73   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9586 on 99 degrees of freedom
# Multiple R-squared:  0.7798,	Adjusted R-squared:  0.7776
# F-statistic: 350.7 on 1 and 99 DF,  p-value: < 2.2e-16

# %% [raw]
# p-value corresponding to coefficient of x leass than 0.001 and t-statistics is 18 standard deviation from mean, standard error is also low, we can say that it is a good estimate.

# %% [markdown]
# ## Ans(b)

# %%
lm.fit1 = lm(x~y)
summary(lm.fit1)
# Out:
# Call:
# lm(formula = x ~ y)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.90848 -0.28101  0.06274  0.24570  0.85736
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03880    0.04266    0.91    0.365
# y            0.38942    0.02099   18.56   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4249 on 98 degrees of freedom
# Multiple R-squared:  0.7784,	Adjusted R-squared:  0.7762
# F-statistic: 344.3 on 1 and 98 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Ans(c)

# %%
plot(x,y)
abline(lm.fit, col="red", lwd=10)
abline(lm.fit1, col="blue", lwd=5)
# Out:
# plot without title

# %% [markdown]
# Both lines are same.

# %% [markdown]
# ## Ans(f)

# %% [markdown]
# t-statistics for regression of x onto y is same as y onto x.

# %% [markdown]
# # Quaestion 12

# %%
t=β/SE(β)
β=∑xiyi∑x2i
SE(β)=∑(yi−xiβ)2(n−1)∑x2i
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:1: unexpected input
# 1: t=β/SE(β)
# 2: β=<e2>
#    ^
# Traceback:
